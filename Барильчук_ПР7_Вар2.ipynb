# %%
import os
import random
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import torchvision
import torch
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets

# %%
data_dir = 'data'

train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)
print(train_dataset)
type(train_dataset)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.09MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 133kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.26MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.89MB/s]
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
# torchvision.datasets.mnist.MNIST

# %%
fig, axs = plt.subplots(5, 5, figsize=(6,6))
for ax in axs.flatten():
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
import torch
from torchvision import datasets, transforms

class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        # Додаємо гаусівський шум до зображення
        noise = torch.randn(tensor.size()) * self.std + self.mean
        return tensor + noise

# Трансформації з додаванням шуму для обох датасетів
transform_with_noise = transforms.Compose([
    transforms.ToTensor(),
    AddGaussianNoise(mean=0.05, std=0.2),
    transforms.Normalize((0.5,), (0.5,))
])
train_dataset = datasets.MNIST(root='path_to_data', train=True, download=True, transform=transform_with_noise)
test_dataset = datasets.MNIST (root='path_to_data', train=False, download=True, transform=transform_with_noise)

fig, axs = plt.subplots (5, 5, figsize=(6,6))
for ax in axs.flatten():
  img, label = random.choice(train_dataset)
  img = img * 0.5 + 0.5
  ax.imshow(np.array(img).squeeze(), cmap='gist_gray')
  ax.set_title(f'Label: {label}')
  ax.set_xticks([])
  ax.set_yticks([])

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.03MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 64.4kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.26MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.15MB/s]

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(len(train_dataset)*0.8), int(m*0.2)])

# %%
batch_size=256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %%
class Encoder(nn.Module):
    def __init__(self, encoded_space_dim):
        super().__init__()

        # Convolutional section
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            nn.ReLU(True)
        )

        # Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        # Linear section
        self.encoder_lin = nn.Sequential(
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            nn.Linear(128, encoded_space_dim)
        )

    def forward(self, x):
        x = self.encoder_cnn(x)
        x = self.flatten(x)
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, encoded_space_dim, fc2_input_dim=128):
        super().__init__()

        # Linear section
        self.decoder_lin = nn.Sequential(
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 7 * 7 * 16),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(16, 7, 7))

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(16, 8, 4, stride=2, padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 1, 4, stride=2, padding=1)
        )

    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        return x

# %%
# Set the random seed for reproducible results
torch.manual_seed(42)

# Initialize the two networks
encoded_space_dim = 4  # Розмір закодованого простору
encoder = Encoder(encoded_space_dim=encoded_space_dim)
decoder = Decoder(encoded_space_dim=encoded_space_dim)

# %%
img, _ = test_dataset[0]
img = img.unsqueeze(0)
print('Original image shape:', img.shape)

# Encode the image
img_enc = encoder(img)
print('Encoded image shape:', img_enc.shape)

# Decode the image
dec_img = decoder(img_enc)
print('Decoded image shape:', dec_img.shape)
# Out:
# Original image shape: torch.Size([1, 1, 28, 28])
# Encoded image shape: torch.Size([1, 4])
# Decoded image shape: torch.Size([1, 1, 28, 28])

# %%
# Define the loss function
loss_fn = torch.nn.MSELoss()

# Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
# Out:
# Selected device: cuda
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
decoder.to(device)
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=784, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(16, 7, 7))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(8, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
# )

# %%
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader:
        # Move tensor to the proper device
        image_batch = image_batch.to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad():
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_batch = image_batch.to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label)
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=5):
    plt.figure(figsize=(10,4.5))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        img = test_dataset[i][0].unsqueeze(0).to(device)
        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            rec_img  = decoder(encoder(img))
        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Original images')
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 20
history={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    train_loss = train_epoch(encoder,decoder,device,train_loader,loss_fn,optim)
    val_loss = test_epoch(encoder,decoder,device,valid_loader,loss_fn)

    print('\\n EPOCH {}/{} \\t train loss {:.3f} \\t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    plot_ae_outputs(encoder,decoder,n=5)
# Out:
# \t partial train loss (single batch): 2.100110
# \t partial train loss (single batch): 2.061291
# \t partial train loss (single batch): 2.033775
# \t partial train loss (single batch): 2.024821
# \t partial train loss (single batch): 2.004818
# \t partial train loss (single batch): 2.003073
# \t partial train loss (single batch): 1.971408
# \t partial train loss (single batch): 1.975464
# \t partial train loss (single batch): 1.942791
# \t partial train loss (single batch): 1.939264
# \t partial train loss (single batch): 1.948990
# \t partial train loss (single batch): 1.920842
# \t partial train loss (single batch): 1.912315
# \t partial train loss (single batch): 1.911180
# \t partial train loss (single batch): 1.894699
# \t partial train loss (single batch): 1.888206
# \t partial train loss (single batch): 1.879511
# \t partial train loss (single batch): 1.866805
# \t partial train loss (single batch): 1.859349
# \t partial train loss (single batch): 1.852954
# \t partial train loss (single batch): 1.842634
# \t partial train loss (single batch): 1.836778
# \t partial train loss (single batch): 1.823194
# \t partial train loss (single batch): 1.818539
# \t partial train loss (single batch): 1.809736
# \t partial train loss (single batch): 1.802602
# \t partial train loss (single batch): 1.790700
# \t partial train loss (single batch): 1.783525
# \t partial train loss (single batch): 1.784243
# \t partial train loss (single batch): 1.777286
# \t partial train loss (single batch): 1.777190
# \t partial train loss (single batch): 1.765159
# \t partial train loss (single batch): 1.758178
# \t partial train loss (single batch): 1.749575
# \t partial train loss (single batch): 1.744208
# \t partial train loss (single batch): 1.724617
# \t partial train loss (single batch): 1.733162
# \t partial train loss (single batch): 1.718586
# \t partial train loss (single batch): 1.710311
# \t partial train loss (single batch): 1.699260
# \t partial train loss (single batch): 1.693040
# \t partial train loss (single batch): 1.684965
# \t partial train loss (single batch): 1.681867
# \t partial train loss (single batch): 1.675099
# \t partial train loss (single batch): 1.669479
# \t partial train loss (single batch): 1.658283
# \t partial train loss (single batch): 1.660676
# \t partial train loss (single batch): 1.647977
# \t partial train loss (single batch): 1.633409
# \t partial train loss (single batch): 1.625643
# \t partial train loss (single batch): 1.630455
# \t partial train loss (single batch): 1.615047
# \t partial train loss (single batch): 1.607654
# \t partial train loss (single batch): 1.605988
# \t partial train loss (single batch): 1.588994
# \t partial train loss (single batch): 1.588282
# \t partial train loss (single batch): 1.576841
# \t partial train loss (single batch): 1.575208
# \t partial train loss (single batch): 1.566504
# \t partial train loss (single batch): 1.566362
# \t partial train loss (single batch): 1.550248
# \t partial train loss (single batch): 1.546281
# \t partial train loss (single batch): 1.542712
# \t partial train loss (single batch): 1.524512
# \t partial train loss (single batch): 1.521117
# \t partial train loss (single batch): 1.515952
# \t partial train loss (single batch): 1.507339
# \t partial train loss (single batch): 1.500425
# \t partial train loss (single batch): 1.500754
# \t partial train loss (single batch): 1.497567
# \t partial train loss (single batch): 1.485957
# \t partial train loss (single batch): 1.483663
# \t partial train loss (single batch): 1.472023
# \t partial train loss (single batch): 1.467818
# \t partial train loss (single batch): 1.460463
# \t partial train loss (single batch): 1.456212
# \t partial train loss (single batch): 1.442772
# \t partial train loss (single batch): 1.445468
# \t partial train loss (single batch): 1.434896
# \t partial train loss (single batch): 1.429001
# \t partial train loss (single batch): 1.419482
# \t partial train loss (single batch): 1.415758
# \t partial train loss (single batch): 1.409436
# \t partial train loss (single batch): 1.407659
# \t partial train loss (single batch): 1.403287
# \t partial train loss (single batch): 1.391845
# \t partial train loss (single batch): 1.385658
# \t partial train loss (single batch): 1.390527
# \t partial train loss (single batch): 1.380103
# \t partial train loss (single batch): 1.372776
# \t partial train loss (single batch): 1.371384
# \t partial train loss (single batch): 1.363764
# \t partial train loss (single batch): 1.361263
# \t partial train loss (single batch): 1.356044
# \t partial train loss (single batch): 1.356360
# \t partial train loss (single batch): 1.346250
# \t partial train loss (single batch): 1.342132
# \t partial train loss (single batch): 1.333210
# \t partial train loss (single batch): 1.326805
# \t partial train loss (single batch): 1.331038
# \t partial train loss (single batch): 1.315593
# \t partial train loss (single batch): 1.318774
# \t partial train loss (single batch): 1.311388
# \t partial train loss (single batch): 1.305458
# \t partial train loss (single batch): 1.302931
# \t partial train loss (single batch): 1.303452
# \t partial train loss (single batch): 1.291198
# \t partial train loss (single batch): 1.290420
# \t partial train loss (single batch): 1.279395
# \t partial train loss (single batch): 1.277919
# \t partial train loss (single batch): 1.281805
# \t partial train loss (single batch): 1.276950
# \t partial train loss (single batch): 1.262272
# \t partial train loss (single batch): 1.265360
# \t partial train loss (single batch): 1.265154
# \t partial train loss (single batch): 1.254320
# \t partial train loss (single batch): 1.254313
# \t partial train loss (single batch): 1.246115
# \t partial train loss (single batch): 1.251284
# \t partial train loss (single batch): 1.240976
# \t partial train loss (single batch): 1.242962
# \t partial train loss (single batch): 1.238553
# \t partial train loss (single batch): 1.230127
# \t partial train loss (single batch): 1.226723
# \t partial train loss (single batch): 1.220514
# \t partial train loss (single batch): 1.220441
# \t partial train loss (single batch): 1.218838
# \t partial train loss (single batch): 1.218409
# \t partial train loss (single batch): 1.214067
# \t partial train loss (single batch): 1.208788
# \t partial train loss (single batch): 1.205174
# \t partial train loss (single batch): 1.199380
# \t partial train loss (single batch): 1.201217
# \t partial train loss (single batch): 1.193183
# \t partial train loss (single batch): 1.189664
# \t partial train loss (single batch): 1.191182
# \t partial train loss (single batch): 1.185341
# \t partial train loss (single batch): 1.184967
# \t partial train loss (single batch): 1.176257
# \t partial train loss (single batch): 1.176333
# \t partial train loss (single batch): 1.173655
# \t partial train loss (single batch): 1.168465
# \t partial train loss (single batch): 1.173138
# \t partial train loss (single batch): 1.168382
# \t partial train loss (single batch): 1.159196
# \t partial train loss (single batch): 1.157091
# \t partial train loss (single batch): 1.159685
# \t partial train loss (single batch): 1.152059
# \t partial train loss (single batch): 1.152580
# \t partial train loss (single batch): 1.149445
# \t partial train loss (single batch): 1.147692
# \t partial train loss (single batch): 1.143299
# \t partial train loss (single batch): 1.141317
# \t partial train loss (single batch): 1.138632
# \t partial train loss (single batch): 1.136912
# \t partial train loss (single batch): 1.134584
# \t partial train loss (single batch): 1.131452
# \t partial train loss (single batch): 1.126568
# \t partial train loss (single batch): 1.129482
# \t partial train loss (single batch): 1.126265
# \t partial train loss (single batch): 1.127241
# \t partial train loss (single batch): 1.122145
# \t partial train loss (single batch): 1.120314
# \t partial train loss (single batch): 1.118173
# \t partial train loss (single batch): 1.120522
# \t partial train loss (single batch): 1.112786
# \t partial train loss (single batch): 1.109395
# \t partial train loss (single batch): 1.110458
# \t partial train loss (single batch): 1.104355
# \t partial train loss (single batch): 1.107049
# \t partial train loss (single batch): 1.095794
# \t partial train loss (single batch): 1.095460
# \t partial train loss (single batch): 1.100520
# \t partial train loss (single batch): 1.094992
# \t partial train loss (single batch): 1.091923
# \t partial train loss (single batch): 1.095017
# \t partial train loss (single batch): 1.091960
# \t partial train loss (single batch): 1.093808
# \t partial train loss (single batch): 1.088712
# \t partial train loss (single batch): 1.086528
# \t partial train loss (single batch): 1.084187
# \t partial train loss (single batch): 1.083746
# \t partial train loss (single batch): 1.081291
# \t partial train loss (single batch): 1.078277
# \t partial train loss (single batch): 1.080839
# \t partial train loss (single batch): 1.079584
# \t partial train loss (single batch): 1.079010
# \t partial train loss (single batch): 1.076590
# \n EPOCH 1/20 \t train loss 1.424 \t val loss 1.068
# \t partial train loss (single batch): 1.073105
# \t partial train loss (single batch): 1.068601
# \t partial train loss (single batch): 1.070846
# \t partial train loss (single batch): 1.067093
# \t partial train loss (single batch): 1.066208
# \t partial train loss (single batch): 1.065613
# \t partial train loss (single batch): 1.061171
# \t partial train loss (single batch): 1.062198
# \t partial train loss (single batch): 1.059110
# \t partial train loss (single batch): 1.056817
# \t partial train loss (single batch): 1.062300
# \t partial train loss (single batch): 1.059567
# \t partial train loss (single batch): 1.055982
# \t partial train loss (single batch): 1.051666
# \t partial train loss (single batch): 1.054253
# \t partial train loss (single batch): 1.053022
# \t partial train loss (single batch): 1.050726
# \t partial train loss (single batch): 1.048864
# \t partial train loss (single batch): 1.047790
# \t partial train loss (single batch): 1.046898
# \t partial train loss (single batch): 1.044703
# \t partial train loss (single batch): 1.048053
# \t partial train loss (single batch): 1.044196
# \t partial train loss (single batch): 1.041443
# \t partial train loss (single batch): 1.039449
# \t partial train loss (single batch): 1.039237
# \t partial train loss (single batch): 1.040660
# \t partial train loss (single batch): 1.036548
# \t partial train loss (single batch): 1.038158
# \t partial train loss (single batch): 1.038779
# \t partial train loss (single batch): 1.035269
# \t partial train loss (single batch): 1.036774
# \t partial train loss (single batch): 1.035267
# \t partial train loss (single batch): 1.032808
# \t partial train loss (single batch): 1.031873
# \t partial train loss (single batch): 1.028467
# \t partial train loss (single batch): 1.032353
# \t partial train loss (single batch): 1.027244
# \t partial train loss (single batch): 1.022828
# \t partial train loss (single batch): 1.028169
# \t partial train loss (single batch): 1.024832
# \t partial train loss (single batch): 1.027578
# \t partial train loss (single batch): 1.023431
# \t partial train loss (single batch): 1.020785
# \t partial train loss (single batch): 1.023230
# \t partial train loss (single batch): 1.019777
# \t partial train loss (single batch): 1.021170
# \t partial train loss (single batch): 1.022800
# \t partial train loss (single batch): 1.017509
# \t partial train loss (single batch): 1.018614
# \t partial train loss (single batch): 1.017175
# \t partial train loss (single batch): 1.014394
# \t partial train loss (single batch): 1.015465
# \t partial train loss (single batch): 1.013334
# \t partial train loss (single batch): 1.012275
# \t partial train loss (single batch): 1.010026
# \t partial train loss (single batch): 1.010374
# \t partial train loss (single batch): 1.012457
# \t partial train loss (single batch): 1.010338
# \t partial train loss (single batch): 1.004819
# \t partial train loss (single batch): 1.004080
# \t partial train loss (single batch): 1.011421
# \t partial train loss (single batch): 1.006783
# \t partial train loss (single batch): 1.004668
# \t partial train loss (single batch): 1.004221
# \t partial train loss (single batch): 1.003590
# \t partial train loss (single batch): 0.999694
# \t partial train loss (single batch): 1.000799
# \t partial train loss (single batch): 1.001905
# \t partial train loss (single batch): 1.002259
# \t partial train loss (single batch): 0.999160
# \t partial train loss (single batch): 1.000637
# \t partial train loss (single batch): 1.000200
# \t partial train loss (single batch): 0.998908
# \t partial train loss (single batch): 1.000046
# \t partial train loss (single batch): 0.993431
# \t partial train loss (single batch): 0.993018
# \t partial train loss (single batch): 0.994528
# \t partial train loss (single batch): 0.992400
# \t partial train loss (single batch): 0.994937
# \t partial train loss (single batch): 0.993974
# \t partial train loss (single batch): 0.994502
# \t partial train loss (single batch): 0.991598
# \t partial train loss (single batch): 0.990679
# \t partial train loss (single batch): 0.994102
# \t partial train loss (single batch): 0.989106
# \t partial train loss (single batch): 0.990238
# \t partial train loss (single batch): 0.991519
# \t partial train loss (single batch): 0.985238
# \t partial train loss (single batch): 0.990516
# \t partial train loss (single batch): 0.989551
# \t partial train loss (single batch): 0.986711
# \t partial train loss (single batch): 0.986012
# \t partial train loss (single batch): 0.985180
# \t partial train loss (single batch): 0.987092
# \t partial train loss (single batch): 0.981118
# \t partial train loss (single batch): 0.982916
# \t partial train loss (single batch): 0.982194
# \t partial train loss (single batch): 0.980841
# \t partial train loss (single batch): 0.983738
# \t partial train loss (single batch): 0.978545
# \t partial train loss (single batch): 0.980859
# \t partial train loss (single batch): 0.977879
# \t partial train loss (single batch): 0.978374
# \t partial train loss (single batch): 0.980748
# \t partial train loss (single batch): 0.980653
# \t partial train loss (single batch): 0.975910
# \t partial train loss (single batch): 0.978833
# \t partial train loss (single batch): 0.974449
# \t partial train loss (single batch): 0.975077
# \t partial train loss (single batch): 0.975523
# \t partial train loss (single batch): 0.976490
# \t partial train loss (single batch): 0.973830
# \t partial train loss (single batch): 0.973104
# \t partial train loss (single batch): 0.973774
# \t partial train loss (single batch): 0.973702
# \t partial train loss (single batch): 0.972764
# \t partial train loss (single batch): 0.968028
# \t partial train loss (single batch): 0.975130
# \t partial train loss (single batch): 0.970493
# \t partial train loss (single batch): 0.972739
# \t partial train loss (single batch): 0.972507
# \t partial train loss (single batch): 0.973003
# \t partial train loss (single batch): 0.971886
# \t partial train loss (single batch): 0.969539
# \t partial train loss (single batch): 0.970063
# \t partial train loss (single batch): 0.969507
# \t partial train loss (single batch): 0.966274
# \t partial train loss (single batch): 0.970485
# \t partial train loss (single batch): 0.968618
# \t partial train loss (single batch): 0.966507
# \t partial train loss (single batch): 0.965609
# \t partial train loss (single batch): 0.966039
# \t partial train loss (single batch): 0.969563
# \t partial train loss (single batch): 0.964494
# \t partial train loss (single batch): 0.966434
# \t partial train loss (single batch): 0.964023
# \t partial train loss (single batch): 0.967582
# \t partial train loss (single batch): 0.964149
# \t partial train loss (single batch): 0.964943
# \t partial train loss (single batch): 0.967645
# \t partial train loss (single batch): 0.962714
# \t partial train loss (single batch): 0.963186
# \t partial train loss (single batch): 0.964411
# \t partial train loss (single batch): 0.960593
# \t partial train loss (single batch): 0.960396
# \t partial train loss (single batch): 0.963254
# \t partial train loss (single batch): 0.960888
# \t partial train loss (single batch): 0.960547
# \t partial train loss (single batch): 0.964851
# \t partial train loss (single batch): 0.960646
# \t partial train loss (single batch): 0.962467
# \t partial train loss (single batch): 0.959543
# \t partial train loss (single batch): 0.959681
# \t partial train loss (single batch): 0.958356
# \t partial train loss (single batch): 0.960150
# \t partial train loss (single batch): 0.956671
# \t partial train loss (single batch): 0.959855
# \t partial train loss (single batch): 0.956469
# \t partial train loss (single batch): 0.959258
# \t partial train loss (single batch): 0.957325
# \t partial train loss (single batch): 0.956167
# \t partial train loss (single batch): 0.954590
# \t partial train loss (single batch): 0.955418
# \t partial train loss (single batch): 0.958840
# \t partial train loss (single batch): 0.954138
# \t partial train loss (single batch): 0.959496
# \t partial train loss (single batch): 0.957438
# \t partial train loss (single batch): 0.955092
# \t partial train loss (single batch): 0.954085
# \t partial train loss (single batch): 0.952112
# \t partial train loss (single batch): 0.955228
# \t partial train loss (single batch): 0.956060
# \t partial train loss (single batch): 0.953352
# \t partial train loss (single batch): 0.954503
# \t partial train loss (single batch): 0.953557
# \t partial train loss (single batch): 0.952624
# \t partial train loss (single batch): 0.956354
# \t partial train loss (single batch): 0.953262
# \t partial train loss (single batch): 0.956351
# \t partial train loss (single batch): 0.953126
# \t partial train loss (single batch): 0.953356
# \t partial train loss (single batch): 0.952865
# \t partial train loss (single batch): 0.953751
# \t partial train loss (single batch): 0.957478
# \t partial train loss (single batch): 0.953202
# \t partial train loss (single batch): 0.953337
# \t partial train loss (single batch): 0.951108
# \n EPOCH 2/20 \t train loss 0.994 \t val loss 0.952
# \t partial train loss (single batch): 0.953953
# \t partial train loss (single batch): 0.947150
# \t partial train loss (single batch): 0.948661
# \t partial train loss (single batch): 0.951149
# \t partial train loss (single batch): 0.946922
# \t partial train loss (single batch): 0.951169
# \t partial train loss (single batch): 0.946854
# \t partial train loss (single batch): 0.952636
# \t partial train loss (single batch): 0.950780
# \t partial train loss (single batch): 0.948098
# \t partial train loss (single batch): 0.948943
# \t partial train loss (single batch): 0.948666
# \t partial train loss (single batch): 0.950078
# \t partial train loss (single batch): 0.950096
# \t partial train loss (single batch): 0.944576
# \t partial train loss (single batch): 0.947624
# \t partial train loss (single batch): 0.946603
# \t partial train loss (single batch): 0.948689
# \t partial train loss (single batch): 0.949644
# \t partial train loss (single batch): 0.949328
# \t partial train loss (single batch): 0.950393
# \t partial train loss (single batch): 0.946111
# \t partial train loss (single batch): 0.945543
# \t partial train loss (single batch): 0.945666
# \t partial train loss (single batch): 0.948521
# \t partial train loss (single batch): 0.944872
# \t partial train loss (single batch): 0.945398
# \t partial train loss (single batch): 0.942887
# \t partial train loss (single batch): 0.947249
# \t partial train loss (single batch): 0.943604
# \t partial train loss (single batch): 0.945088
# \t partial train loss (single batch): 0.947365
# \t partial train loss (single batch): 0.944892
# \t partial train loss (single batch): 0.944130
# \t partial train loss (single batch): 0.949211
# \t partial train loss (single batch): 0.943393
# \t partial train loss (single batch): 0.944548
# \t partial train loss (single batch): 0.941790
# \t partial train loss (single batch): 0.941372
# \t partial train loss (single batch): 0.945221
# \t partial train loss (single batch): 0.945605
# \t partial train loss (single batch): 0.943324
# \t partial train loss (single batch): 0.945176
# \t partial train loss (single batch): 0.942048
# \t partial train loss (single batch): 0.940404
# \t partial train loss (single batch): 0.942483
# \t partial train loss (single batch): 0.947257
# \t partial train loss (single batch): 0.946047
# \t partial train loss (single batch): 0.939341
# \t partial train loss (single batch): 0.941688
# \t partial train loss (single batch): 0.945191
# \t partial train loss (single batch): 0.942376
# \t partial train loss (single batch): 0.941733
# \t partial train loss (single batch): 0.941141
# \t partial train loss (single batch): 0.939953
# \t partial train loss (single batch): 0.940411
# \t partial train loss (single batch): 0.941109
# \t partial train loss (single batch): 0.938187
# \t partial train loss (single batch): 0.943405
# \t partial train loss (single batch): 0.943218
# \t partial train loss (single batch): 0.943166
# \t partial train loss (single batch): 0.942462
# \t partial train loss (single batch): 0.943833
# \t partial train loss (single batch): 0.943861
# \t partial train loss (single batch): 0.937868
# \t partial train loss (single batch): 0.939490
# \t partial train loss (single batch): 0.940124
# \t partial train loss (single batch): 0.938872
# \t partial train loss (single batch): 0.941236
# \t partial train loss (single batch): 0.936255
# \t partial train loss (single batch): 0.938834
# \t partial train loss (single batch): 0.940400
# \t partial train loss (single batch): 0.941470
# \t partial train loss (single batch): 0.940368
# \t partial train loss (single batch): 0.941343
# \t partial train loss (single batch): 0.937820
# \t partial train loss (single batch): 0.936061
# \t partial train loss (single batch): 0.936987
# \t partial train loss (single batch): 0.937720
# \t partial train loss (single batch): 0.940346
# \t partial train loss (single batch): 0.937204
# \t partial train loss (single batch): 0.936148
# \t partial train loss (single batch): 0.934722
# \t partial train loss (single batch): 0.936831
# \t partial train loss (single batch): 0.938704
# \t partial train loss (single batch): 0.939192
# \t partial train loss (single batch): 0.935674
# \t partial train loss (single batch): 0.938516
# \t partial train loss (single batch): 0.938734
# \t partial train loss (single batch): 0.941440
# \t partial train loss (single batch): 0.939297
# \t partial train loss (single batch): 0.936536
# \t partial train loss (single batch): 0.938503
# \t partial train loss (single batch): 0.942681
# \t partial train loss (single batch): 0.939173
# \t partial train loss (single batch): 0.937768
# \t partial train loss (single batch): 0.935752
# \t partial train loss (single batch): 0.935921
# \t partial train loss (single batch): 0.935312
# \t partial train loss (single batch): 0.938612
# \t partial train loss (single batch): 0.932681
# \t partial train loss (single batch): 0.935736
# \t partial train loss (single batch): 0.936281
# \t partial train loss (single batch): 0.937738
# \t partial train loss (single batch): 0.934826
# \t partial train loss (single batch): 0.938316
# \t partial train loss (single batch): 0.935463
# \t partial train loss (single batch): 0.934328
# \t partial train loss (single batch): 0.933783
# \t partial train loss (single batch): 0.934552
# \t partial train loss (single batch): 0.938902
# \t partial train loss (single batch): 0.933737
# \t partial train loss (single batch): 0.932750
# \t partial train loss (single batch): 0.935400
# \t partial train loss (single batch): 0.937964
# \t partial train loss (single batch): 0.933375
# \t partial train loss (single batch): 0.938015
# \t partial train loss (single batch): 0.931311
# \t partial train loss (single batch): 0.935259
# \t partial train loss (single batch): 0.935855
# \t partial train loss (single batch): 0.935013
# \t partial train loss (single batch): 0.936499
# \t partial train loss (single batch): 0.937129
# \t partial train loss (single batch): 0.934544
# \t partial train loss (single batch): 0.935724
# \t partial train loss (single batch): 0.932280
# \t partial train loss (single batch): 0.934093
# \t partial train loss (single batch): 0.930553
# \t partial train loss (single batch): 0.934845
# \t partial train loss (single batch): 0.934173
# \t partial train loss (single batch): 0.932681
# \t partial train loss (single batch): 0.933539
# \t partial train loss (single batch): 0.935761
# \t partial train loss (single batch): 0.932724
# \t partial train loss (single batch): 0.929749
# \t partial train loss (single batch): 0.931110
# \t partial train loss (single batch): 0.931403
# \t partial train loss (single batch): 0.932330
# \t partial train loss (single batch): 0.930209
# \t partial train loss (single batch): 0.934444
# \t partial train loss (single batch): 0.933312
# \t partial train loss (single batch): 0.931814
# \t partial train loss (single batch): 0.934776
# \t partial train loss (single batch): 0.931378
# \t partial train loss (single batch): 0.930776
# \t partial train loss (single batch): 0.933294
# \t partial train loss (single batch): 0.935720
# \t partial train loss (single batch): 0.933408
# \t partial train loss (single batch): 0.931357
# \t partial train loss (single batch): 0.934937
# \t partial train loss (single batch): 0.935151
# \t partial train loss (single batch): 0.931170
# \t partial train loss (single batch): 0.935244
# \t partial train loss (single batch): 0.933429
# \t partial train loss (single batch): 0.929892
# \t partial train loss (single batch): 0.931868
# \t partial train loss (single batch): 0.935551
# \t partial train loss (single batch): 0.935662
# \t partial train loss (single batch): 0.931702
# \t partial train loss (single batch): 0.935723
# \t partial train loss (single batch): 0.931114
# \t partial train loss (single batch): 0.929208
# \t partial train loss (single batch): 0.929036
# \t partial train loss (single batch): 0.931912
# \t partial train loss (single batch): 0.931784
# \t partial train loss (single batch): 0.927202
# \t partial train loss (single batch): 0.930143
# \t partial train loss (single batch): 0.932258
# \t partial train loss (single batch): 0.932191
# \t partial train loss (single batch): 0.930999
# \t partial train loss (single batch): 0.926908
# \t partial train loss (single batch): 0.926505
# \t partial train loss (single batch): 0.931749
# \t partial train loss (single batch): 0.929759
# \t partial train loss (single batch): 0.931033
# \t partial train loss (single batch): 0.927398
# \t partial train loss (single batch): 0.926202
# \t partial train loss (single batch): 0.930261
# \t partial train loss (single batch): 0.929948
# \t partial train loss (single batch): 0.928355
# \t partial train loss (single batch): 0.931279
# \t partial train loss (single batch): 0.932400
# \t partial train loss (single batch): 0.929853
# \t partial train loss (single batch): 0.929800
# \t partial train loss (single batch): 0.934045
# \t partial train loss (single batch): 0.930180
# \t partial train loss (single batch): 0.931410
# \t partial train loss (single batch): 0.931408
# \n EPOCH 3/20 \t train loss 0.938 \t val loss 0.930
# \t partial train loss (single batch): 0.930072
# \t partial train loss (single batch): 0.928530
# \t partial train loss (single batch): 0.927187
# \t partial train loss (single batch): 0.927146
# \t partial train loss (single batch): 0.931068
# \t partial train loss (single batch): 0.926190
# \t partial train loss (single batch): 0.928888
# \t partial train loss (single batch): 0.932602
# \t partial train loss (single batch): 0.927799
# \t partial train loss (single batch): 0.930422
# \t partial train loss (single batch): 0.931736
# \t partial train loss (single batch): 0.925983
# \t partial train loss (single batch): 0.930916
# \t partial train loss (single batch): 0.927582
# \t partial train loss (single batch): 0.925562
# \t partial train loss (single batch): 0.929907
# \t partial train loss (single batch): 0.929190
# \t partial train loss (single batch): 0.927612
# \t partial train loss (single batch): 0.929640
# \t partial train loss (single batch): 0.927508
# \t partial train loss (single batch): 0.927975
# \t partial train loss (single batch): 0.930622
# \t partial train loss (single batch): 0.930431
# \t partial train loss (single batch): 0.927190
# \t partial train loss (single batch): 0.928514
# \t partial train loss (single batch): 0.931913
# \t partial train loss (single batch): 0.926426
# \t partial train loss (single batch): 0.926987
# \t partial train loss (single batch): 0.929224
# \t partial train loss (single batch): 0.926423
# \t partial train loss (single batch): 0.928789
# \t partial train loss (single batch): 0.927241
# \t partial train loss (single batch): 0.930540
# \t partial train loss (single batch): 0.925364
# \t partial train loss (single batch): 0.928107
# \t partial train loss (single batch): 0.927174
# \t partial train loss (single batch): 0.927250
# \t partial train loss (single batch): 0.930645
# \t partial train loss (single batch): 0.922865
# \t partial train loss (single batch): 0.928285
# \t partial train loss (single batch): 0.925687
# \t partial train loss (single batch): 0.926395
# \t partial train loss (single batch): 0.929656
# \t partial train loss (single batch): 0.923820
# \t partial train loss (single batch): 0.927036
# \t partial train loss (single batch): 0.927477
# \t partial train loss (single batch): 0.932975
# \t partial train loss (single batch): 0.926471
# \t partial train loss (single batch): 0.925267
# \t partial train loss (single batch): 0.928179
# \t partial train loss (single batch): 0.925189
# \t partial train loss (single batch): 0.924829
# \t partial train loss (single batch): 0.926789
# \t partial train loss (single batch): 0.925036
# \t partial train loss (single batch): 0.928321
# \t partial train loss (single batch): 0.926660
# \t partial train loss (single batch): 0.924139
# \t partial train loss (single batch): 0.926073
# \t partial train loss (single batch): 0.927784
# \t partial train loss (single batch): 0.928128
# \t partial train loss (single batch): 0.924899
# \t partial train loss (single batch): 0.928315
# \t partial train loss (single batch): 0.925456
# \t partial train loss (single batch): 0.925977
# \t partial train loss (single batch): 0.922828
# \t partial train loss (single batch): 0.925599
# \t partial train loss (single batch): 0.924589
# \t partial train loss (single batch): 0.927966
# \t partial train loss (single batch): 0.924344
# \t partial train loss (single batch): 0.926210
# \t partial train loss (single batch): 0.927367
# \t partial train loss (single batch): 0.923444
# \t partial train loss (single batch): 0.926858
# \t partial train loss (single batch): 0.924234
# \t partial train loss (single batch): 0.924897
# \t partial train loss (single batch): 0.923966
# \t partial train loss (single batch): 0.923328
# \t partial train loss (single batch): 0.924845
# \t partial train loss (single batch): 0.924928
# \t partial train loss (single batch): 0.921452
# \t partial train loss (single batch): 0.920720
# \t partial train loss (single batch): 0.921070
# \t partial train loss (single batch): 0.922918
# \t partial train loss (single batch): 0.926183
# \t partial train loss (single batch): 0.927210
# \t partial train loss (single batch): 0.924139
# \t partial train loss (single batch): 0.925126
# \t partial train loss (single batch): 0.927832
# \t partial train loss (single batch): 0.924059
# \t partial train loss (single batch): 0.927147
# \t partial train loss (single batch): 0.923491
# \t partial train loss (single batch): 0.922626
# \t partial train loss (single batch): 0.925469
# \t partial train loss (single batch): 0.924239
# \t partial train loss (single batch): 0.928258
# \t partial train loss (single batch): 0.925274
# \t partial train loss (single batch): 0.926265
# \t partial train loss (single batch): 0.924674
# \t partial train loss (single batch): 0.921570
# \t partial train loss (single batch): 0.922703
# \t partial train loss (single batch): 0.920316
# \t partial train loss (single batch): 0.925043
# \t partial train loss (single batch): 0.924659
# \t partial train loss (single batch): 0.923008
# \t partial train loss (single batch): 0.926383
# \t partial train loss (single batch): 0.928294
# \t partial train loss (single batch): 0.920463
# \t partial train loss (single batch): 0.926414
# \t partial train loss (single batch): 0.920906
# \t partial train loss (single batch): 0.921439
# \t partial train loss (single batch): 0.924561
# \t partial train loss (single batch): 0.921749
# \t partial train loss (single batch): 0.920300
# \t partial train loss (single batch): 0.924848
# \t partial train loss (single batch): 0.923833
# \t partial train loss (single batch): 0.920888
# \t partial train loss (single batch): 0.922580
# \t partial train loss (single batch): 0.922062
# \t partial train loss (single batch): 0.924089
# \t partial train loss (single batch): 0.921600
# \t partial train loss (single batch): 0.920913
# \t partial train loss (single batch): 0.923212
# \t partial train loss (single batch): 0.924169
# \t partial train loss (single batch): 0.923208
# \t partial train loss (single batch): 0.920385
# \t partial train loss (single batch): 0.922059
# \t partial train loss (single batch): 0.921589
# \t partial train loss (single batch): 0.921974
# \t partial train loss (single batch): 0.924202
# \t partial train loss (single batch): 0.923758
# \t partial train loss (single batch): 0.925283
# \t partial train loss (single batch): 0.923001
# \t partial train loss (single batch): 0.921523
# \t partial train loss (single batch): 0.923069
# \t partial train loss (single batch): 0.921644
# \t partial train loss (single batch): 0.924988
# \t partial train loss (single batch): 0.922420
# \t partial train loss (single batch): 0.920515
# \t partial train loss (single batch): 0.917709
# \t partial train loss (single batch): 0.922453
# \t partial train loss (single batch): 0.924758
# \t partial train loss (single batch): 0.921377
# \t partial train loss (single batch): 0.927679
# \t partial train loss (single batch): 0.920095
# \t partial train loss (single batch): 0.918753
# \t partial train loss (single batch): 0.920817
# \t partial train loss (single batch): 0.923970
# \t partial train loss (single batch): 0.926206
# \t partial train loss (single batch): 0.923261
# \t partial train loss (single batch): 0.922072
# \t partial train loss (single batch): 0.926133
# \t partial train loss (single batch): 0.922096
# \t partial train loss (single batch): 0.922710
# \t partial train loss (single batch): 0.923483
# \t partial train loss (single batch): 0.922560
# \t partial train loss (single batch): 0.924724
# \t partial train loss (single batch): 0.923330
# \t partial train loss (single batch): 0.922059
# \t partial train loss (single batch): 0.922082
# \t partial train loss (single batch): 0.921895
# \t partial train loss (single batch): 0.925158
# \t partial train loss (single batch): 0.918487
# \t partial train loss (single batch): 0.923247
# \t partial train loss (single batch): 0.919997
# \t partial train loss (single batch): 0.919854
# \t partial train loss (single batch): 0.921817
# \t partial train loss (single batch): 0.922712
# \t partial train loss (single batch): 0.921246
# \t partial train loss (single batch): 0.920355
# \t partial train loss (single batch): 0.920786
# \t partial train loss (single batch): 0.919016
# \t partial train loss (single batch): 0.920476
# \t partial train loss (single batch): 0.922580
# \t partial train loss (single batch): 0.920440
# \t partial train loss (single batch): 0.920617
# \t partial train loss (single batch): 0.918907
# \t partial train loss (single batch): 0.921806
# \t partial train loss (single batch): 0.924225
# \t partial train loss (single batch): 0.922657
# \t partial train loss (single batch): 0.921654
# \t partial train loss (single batch): 0.924344
# \t partial train loss (single batch): 0.920787
# \t partial train loss (single batch): 0.920799
# \t partial train loss (single batch): 0.920816
# \t partial train loss (single batch): 0.923544
# \t partial train loss (single batch): 0.923898
# \t partial train loss (single batch): 0.921125
# \t partial train loss (single batch): 0.922739
# \n EPOCH 4/20 \t train loss 0.925 \t val loss 0.922
# \t partial train loss (single batch): 0.922123
# \t partial train loss (single batch): 0.920982
# \t partial train loss (single batch): 0.917927
# \t partial train loss (single batch): 0.920161
# \t partial train loss (single batch): 0.916446
# \t partial train loss (single batch): 0.918315
# \t partial train loss (single batch): 0.917291
# \t partial train loss (single batch): 0.920150
# \t partial train loss (single batch): 0.920657
# \t partial train loss (single batch): 0.919774
# \t partial train loss (single batch): 0.923485
# \t partial train loss (single batch): 0.923586
# \t partial train loss (single batch): 0.923697
# \t partial train loss (single batch): 0.918496
# \t partial train loss (single batch): 0.920668
# \t partial train loss (single batch): 0.922386
# \t partial train loss (single batch): 0.918699
# \t partial train loss (single batch): 0.918931
# \t partial train loss (single batch): 0.919037
# \t partial train loss (single batch): 0.916858
# \t partial train loss (single batch): 0.917865
# \t partial train loss (single batch): 0.921065
# \t partial train loss (single batch): 0.921935
# \t partial train loss (single batch): 0.919681
# \t partial train loss (single batch): 0.916963
# \t partial train loss (single batch): 0.917419
# \t partial train loss (single batch): 0.920321
# \t partial train loss (single batch): 0.919673
# \t partial train loss (single batch): 0.920081
# \t partial train loss (single batch): 0.919086
# \t partial train loss (single batch): 0.919721
# \t partial train loss (single batch): 0.919582
# \t partial train loss (single batch): 0.919165
# \t partial train loss (single batch): 0.921113
# \t partial train loss (single batch): 0.921552
# \t partial train loss (single batch): 0.918066
# \t partial train loss (single batch): 0.925049
# \t partial train loss (single batch): 0.920948
# \t partial train loss (single batch): 0.919542
# \t partial train loss (single batch): 0.919549
# \t partial train loss (single batch): 0.921725
# \t partial train loss (single batch): 0.919008
# \t partial train loss (single batch): 0.920891
# \t partial train loss (single batch): 0.921215
# \t partial train loss (single batch): 0.920009
# \t partial train loss (single batch): 0.920448
# \t partial train loss (single batch): 0.920874
# \t partial train loss (single batch): 0.921161
# \t partial train loss (single batch): 0.917450
# \t partial train loss (single batch): 0.916873
# \t partial train loss (single batch): 0.923294
# \t partial train loss (single batch): 0.917952
# \t partial train loss (single batch): 0.919806
# \t partial train loss (single batch): 0.922456
# \t partial train loss (single batch): 0.919129
# \t partial train loss (single batch): 0.915084
# \t partial train loss (single batch): 0.917185
# \t partial train loss (single batch): 0.921721
# \t partial train loss (single batch): 0.918751
# \t partial train loss (single batch): 0.919131
# \t partial train loss (single batch): 0.917546
# \t partial train loss (single batch): 0.920033
# \t partial train loss (single batch): 0.916535
# \t partial train loss (single batch): 0.917162
# \t partial train loss (single batch): 0.918331
# \t partial train loss (single batch): 0.920564
# \t partial train loss (single batch): 0.920149
# \t partial train loss (single batch): 0.917222
# \t partial train loss (single batch): 0.919345
# \t partial train loss (single batch): 0.923111
# \t partial train loss (single batch): 0.919313
# \t partial train loss (single batch): 0.920712
# \t partial train loss (single batch): 0.920171
# \t partial train loss (single batch): 0.918643
# \t partial train loss (single batch): 0.917441
# \t partial train loss (single batch): 0.921049
# \t partial train loss (single batch): 0.917557
# \t partial train loss (single batch): 0.918766
# \t partial train loss (single batch): 0.916604
# \t partial train loss (single batch): 0.922034
# \t partial train loss (single batch): 0.918972
# \t partial train loss (single batch): 0.917254
# \t partial train loss (single batch): 0.914549
# \t partial train loss (single batch): 0.918412
# \t partial train loss (single batch): 0.918692
# \t partial train loss (single batch): 0.912446
# \t partial train loss (single batch): 0.918832
# \t partial train loss (single batch): 0.918957
# \t partial train loss (single batch): 0.916876
# \t partial train loss (single batch): 0.919122
# \t partial train loss (single batch): 0.918678
# \t partial train loss (single batch): 0.919807
# \t partial train loss (single batch): 0.919766
# \t partial train loss (single batch): 0.916896
# \t partial train loss (single batch): 0.919573
# \t partial train loss (single batch): 0.919271
# \t partial train loss (single batch): 0.917598
# \t partial train loss (single batch): 0.915384
# \t partial train loss (single batch): 0.914451
# \t partial train loss (single batch): 0.919247
# \t partial train loss (single batch): 0.914083
# \t partial train loss (single batch): 0.919406
# \t partial train loss (single batch): 0.919133
# \t partial train loss (single batch): 0.919717
# \t partial train loss (single batch): 0.916601
# \t partial train loss (single batch): 0.920448
# \t partial train loss (single batch): 0.916608
# \t partial train loss (single batch): 0.916547
# \t partial train loss (single batch): 0.918262
# \t partial train loss (single batch): 0.919793
# \t partial train loss (single batch): 0.920796
# \t partial train loss (single batch): 0.917581
# \t partial train loss (single batch): 0.915599
# \t partial train loss (single batch): 0.916503
# \t partial train loss (single batch): 0.917022
# \t partial train loss (single batch): 0.919075
# \t partial train loss (single batch): 0.917678
# \t partial train loss (single batch): 0.914535
# \t partial train loss (single batch): 0.919373
# \t partial train loss (single batch): 0.915220
# \t partial train loss (single batch): 0.918224
# \t partial train loss (single batch): 0.919228
# \t partial train loss (single batch): 0.921185
# \t partial train loss (single batch): 0.915570
# \t partial train loss (single batch): 0.917521
# \t partial train loss (single batch): 0.917356
# \t partial train loss (single batch): 0.918055
# \t partial train loss (single batch): 0.918504
# \t partial train loss (single batch): 0.919736
# \t partial train loss (single batch): 0.918683
# \t partial train loss (single batch): 0.917730
# \t partial train loss (single batch): 0.917854
# \t partial train loss (single batch): 0.917715
# \t partial train loss (single batch): 0.918934
# \t partial train loss (single batch): 0.914527
# \t partial train loss (single batch): 0.918312
# \t partial train loss (single batch): 0.918464
# \t partial train loss (single batch): 0.921047
# \t partial train loss (single batch): 0.911288
# \t partial train loss (single batch): 0.923144
# \t partial train loss (single batch): 0.917324
# \t partial train loss (single batch): 0.916277
# \t partial train loss (single batch): 0.920519
# \t partial train loss (single batch): 0.915375
# \t partial train loss (single batch): 0.917198
# \t partial train loss (single batch): 0.915012
# \t partial train loss (single batch): 0.919877
# \t partial train loss (single batch): 0.919691
# \t partial train loss (single batch): 0.915114
# \t partial train loss (single batch): 0.918387
# \t partial train loss (single batch): 0.918147
# \t partial train loss (single batch): 0.919265
# \t partial train loss (single batch): 0.921102
# \t partial train loss (single batch): 0.917147
# \t partial train loss (single batch): 0.914528
# \t partial train loss (single batch): 0.919396
# \t partial train loss (single batch): 0.917782
# \t partial train loss (single batch): 0.917837
# \t partial train loss (single batch): 0.917014
# \t partial train loss (single batch): 0.916588
# \t partial train loss (single batch): 0.915518
# \t partial train loss (single batch): 0.914781
# \t partial train loss (single batch): 0.917542
# \t partial train loss (single batch): 0.913003
# \t partial train loss (single batch): 0.918667
# \t partial train loss (single batch): 0.920679
# \t partial train loss (single batch): 0.920276
# \t partial train loss (single batch): 0.917452
# \t partial train loss (single batch): 0.918942
# \t partial train loss (single batch): 0.914459
# \t partial train loss (single batch): 0.915049
# \t partial train loss (single batch): 0.915788
# \t partial train loss (single batch): 0.917551
# \t partial train loss (single batch): 0.917279
# \t partial train loss (single batch): 0.912884
# \t partial train loss (single batch): 0.917939
# \t partial train loss (single batch): 0.915433
# \t partial train loss (single batch): 0.920392
# \t partial train loss (single batch): 0.916983
# \t partial train loss (single batch): 0.917019
# \t partial train loss (single batch): 0.914436
# \t partial train loss (single batch): 0.918595
# \t partial train loss (single batch): 0.919949
# \t partial train loss (single batch): 0.918721
# \t partial train loss (single batch): 0.917940
# \t partial train loss (single batch): 0.918542
# \t partial train loss (single batch): 0.915377
# \t partial train loss (single batch): 0.921401
# \n EPOCH 5/20 \t train loss 0.919 \t val loss 0.916
# \t partial train loss (single batch): 0.916660
# \t partial train loss (single batch): 0.914776
# \t partial train loss (single batch): 0.914483
# \t partial train loss (single batch): 0.915535
# \t partial train loss (single batch): 0.915094
# \t partial train loss (single batch): 0.916280
# \t partial train loss (single batch): 0.914696
# \t partial train loss (single batch): 0.915503
# \t partial train loss (single batch): 0.915983
# \t partial train loss (single batch): 0.912618
# \t partial train loss (single batch): 0.918842
# \t partial train loss (single batch): 0.915155
# \t partial train loss (single batch): 0.914268
# \t partial train loss (single batch): 0.916483
# \t partial train loss (single batch): 0.916195
# \t partial train loss (single batch): 0.917111
# \t partial train loss (single batch): 0.918051
# \t partial train loss (single batch): 0.915012
# \t partial train loss (single batch): 0.914605
# \t partial train loss (single batch): 0.917662
# \t partial train loss (single batch): 0.916247
# \t partial train loss (single batch): 0.920094
# \t partial train loss (single batch): 0.916383
# \t partial train loss (single batch): 0.915085
# \t partial train loss (single batch): 0.913020
# \t partial train loss (single batch): 0.917540
# \t partial train loss (single batch): 0.915088
# \t partial train loss (single batch): 0.914219
# \t partial train loss (single batch): 0.917011
# \t partial train loss (single batch): 0.915735
# \t partial train loss (single batch): 0.915137
# \t partial train loss (single batch): 0.914523
# \t partial train loss (single batch): 0.914974
# \t partial train loss (single batch): 0.915824
# \t partial train loss (single batch): 0.917376
# \t partial train loss (single batch): 0.914750
# \t partial train loss (single batch): 0.917932
# \t partial train loss (single batch): 0.916129
# \t partial train loss (single batch): 0.910890
# \t partial train loss (single batch): 0.916442
# \t partial train loss (single batch): 0.914812
# \t partial train loss (single batch): 0.915612
# \t partial train loss (single batch): 0.916791
# \t partial train loss (single batch): 0.912761
# \t partial train loss (single batch): 0.916208
# \t partial train loss (single batch): 0.917025
# \t partial train loss (single batch): 0.918546
# \t partial train loss (single batch): 0.915856
# \t partial train loss (single batch): 0.911874
# \t partial train loss (single batch): 0.914227
# \t partial train loss (single batch): 0.914460
# \t partial train loss (single batch): 0.916397
# \t partial train loss (single batch): 0.913910
# \t partial train loss (single batch): 0.914701
# \t partial train loss (single batch): 0.912769
# \t partial train loss (single batch): 0.915198
# \t partial train loss (single batch): 0.910824
# \t partial train loss (single batch): 0.917370
# \t partial train loss (single batch): 0.918302
# \t partial train loss (single batch): 0.916306
# \t partial train loss (single batch): 0.911729
# \t partial train loss (single batch): 0.917248
# \t partial train loss (single batch): 0.912975
# \t partial train loss (single batch): 0.914184
# \t partial train loss (single batch): 0.914499
# \t partial train loss (single batch): 0.914520
# \t partial train loss (single batch): 0.913352
# \t partial train loss (single batch): 0.915508
# \t partial train loss (single batch): 0.914129
# \t partial train loss (single batch): 0.916029
# \t partial train loss (single batch): 0.915628
# \t partial train loss (single batch): 0.916636
# \t partial train loss (single batch): 0.914994
# \t partial train loss (single batch): 0.912619
# \t partial train loss (single batch): 0.913230
# ...
# \t partial train loss (single batch): 0.892086
# \t partial train loss (single batch): 0.894717
# \t partial train loss (single batch): 0.893605
# \t partial train loss (single batch): 0.889546
# \t partial train loss (single batch): 0.892361
# \t partial train loss (single batch): 0.892266
# \t partial train loss (single batch): 0.890159
# \t partial train loss (single batch): 0.892026
# \t partial train loss (single batch): 0.895821
# \t partial train loss (single batch): 0.894602
# \t partial train loss (single batch): 0.894128
# \t partial train loss (single batch): 0.891693
# \t partial train loss (single batch): 0.894602
# \t partial train loss (single batch): 0.892928
# \t partial train loss (single batch): 0.893677
# \t partial train loss (single batch): 0.893887
# \t partial train loss (single batch): 0.891072
# \t partial train loss (single batch): 0.894372
# \t partial train loss (single batch): 0.891254
# \t partial train loss (single batch): 0.895969
# \t partial train loss (single batch): 0.891249
# \t partial train loss (single batch): 0.895795
# \t partial train loss (single batch): 0.891437
# \t partial train loss (single batch): 0.898340
# \t partial train loss (single batch): 0.894917
# \t partial train loss (single batch): 0.894171
# \t partial train loss (single batch): 0.897904
# \t partial train loss (single batch): 0.898536
# \t partial train loss (single batch): 0.892937
# \t partial train loss (single batch): 0.893387
# \t partial train loss (single batch): 0.893927
# \t partial train loss (single batch): 0.896210
# \t partial train loss (single batch): 0.895399
# \t partial train loss (single batch): 0.895646
# \t partial train loss (single batch): 0.896542
# \t partial train loss (single batch): 0.894466
# \t partial train loss (single batch): 0.889474
# \t partial train loss (single batch): 0.895657
# \t partial train loss (single batch): 0.890861
# \t partial train loss (single batch): 0.893877
# \t partial train loss (single batch): 0.891556
# \t partial train loss (single batch): 0.895095
# \t partial train loss (single batch): 0.891217
# \t partial train loss (single batch): 0.889116
# \t partial train loss (single batch): 0.894927
# \t partial train loss (single batch): 0.887546
# \t partial train loss (single batch): 0.894569
# \t partial train loss (single batch): 0.890622
# \t partial train loss (single batch): 0.893968
# \t partial train loss (single batch): 0.896210
# \t partial train loss (single batch): 0.892855
# \t partial train loss (single batch): 0.894944
# \t partial train loss (single batch): 0.893679
# \t partial train loss (single batch): 0.894603
# \t partial train loss (single batch): 0.894712
# \t partial train loss (single batch): 0.895254
# \t partial train loss (single batch): 0.892654
# \t partial train loss (single batch): 0.897119
# \t partial train loss (single batch): 0.893595
# \t partial train loss (single batch): 0.888978
# \t partial train loss (single batch): 0.892134
# \t partial train loss (single batch): 0.894696
# \t partial train loss (single batch): 0.893129
# \t partial train loss (single batch): 0.891760
# \t partial train loss (single batch): 0.894644
# \t partial train loss (single batch): 0.896223
# \t partial train loss (single batch): 0.893288
# \t partial train loss (single batch): 0.892877
# \t partial train loss (single batch): 0.887810
# \t partial train loss (single batch): 0.893597
# \t partial train loss (single batch): 0.889190
# \t partial train loss (single batch): 0.890844
# \t partial train loss (single batch): 0.895572
# \t partial train loss (single batch): 0.891567
# \t partial train loss (single batch): 0.890432
# \t partial train loss (single batch): 0.891579
# \t partial train loss (single batch): 0.894784
# \t partial train loss (single batch): 0.890453
# \t partial train loss (single batch): 0.890252
# \t partial train loss (single batch): 0.892361
# \t partial train loss (single batch): 0.894906
# \t partial train loss (single batch): 0.888692
# \t partial train loss (single batch): 0.891192
# \t partial train loss (single batch): 0.893729
# \t partial train loss (single batch): 0.895731
# \t partial train loss (single batch): 0.893058
# \t partial train loss (single batch): 0.892516
# \t partial train loss (single batch): 0.890536
# \t partial train loss (single batch): 0.891768
# \t partial train loss (single batch): 0.893672
# \t partial train loss (single batch): 0.896645
# \t partial train loss (single batch): 0.891811
# \t partial train loss (single batch): 0.894316
# \t partial train loss (single batch): 0.891683
# \t partial train loss (single batch): 0.894116
# \t partial train loss (single batch): 0.889247
# \t partial train loss (single batch): 0.891169
# \t partial train loss (single batch): 0.893336
# \t partial train loss (single batch): 0.893619
# \t partial train loss (single batch): 0.893342
# \t partial train loss (single batch): 0.894761
# \t partial train loss (single batch): 0.892690
# \t partial train loss (single batch): 0.892157
# \t partial train loss (single batch): 0.891805
# \t partial train loss (single batch): 0.896488
# \t partial train loss (single batch): 0.888545
# \t partial train loss (single batch): 0.890785
# \t partial train loss (single batch): 0.890223
# \t partial train loss (single batch): 0.896332
# \t partial train loss (single batch): 0.893238
# \t partial train loss (single batch): 0.891700
# \t partial train loss (single batch): 0.893327
# \t partial train loss (single batch): 0.891740
# \t partial train loss (single batch): 0.895484
# \t partial train loss (single batch): 0.893494
# \t partial train loss (single batch): 0.894854
# \t partial train loss (single batch): 0.890723
# \t partial train loss (single batch): 0.894404
# \t partial train loss (single batch): 0.891813
# \t partial train loss (single batch): 0.891422
# \t partial train loss (single batch): 0.893638
# \t partial train loss (single batch): 0.900726
# \t partial train loss (single batch): 0.887411
# \t partial train loss (single batch): 0.891877
# \t partial train loss (single batch): 0.890939
# \t partial train loss (single batch): 0.889031
# \t partial train loss (single batch): 0.894310
# \t partial train loss (single batch): 0.892667
# \t partial train loss (single batch): 0.897577
# \t partial train loss (single batch): 0.891759
# \t partial train loss (single batch): 0.893534
# \t partial train loss (single batch): 0.889650
# \t partial train loss (single batch): 0.892369
# \t partial train loss (single batch): 0.890117
# \t partial train loss (single batch): 0.893748
# \t partial train loss (single batch): 0.892404
# \t partial train loss (single batch): 0.890441
# \t partial train loss (single batch): 0.890056
# \t partial train loss (single batch): 0.894657
# \t partial train loss (single batch): 0.893486
# \t partial train loss (single batch): 0.892580
# \t partial train loss (single batch): 0.888410
# \t partial train loss (single batch): 0.894365
# \t partial train loss (single batch): 0.892969
# \t partial train loss (single batch): 0.889298
# \t partial train loss (single batch): 0.890718
# \t partial train loss (single batch): 0.897849
# \t partial train loss (single batch): 0.892147
# \t partial train loss (single batch): 0.892165
# \t partial train loss (single batch): 0.892527
# \n EPOCH 19/20 \t train loss 0.893 \t val loss 0.894
# \t partial train loss (single batch): 0.896909
# \t partial train loss (single batch): 0.890480
# \t partial train loss (single batch): 0.891804
# \t partial train loss (single batch): 0.890656
# \t partial train loss (single batch): 0.894134
# \t partial train loss (single batch): 0.894276
# \t partial train loss (single batch): 0.892088
# \t partial train loss (single batch): 0.892541
# \t partial train loss (single batch): 0.891678
# \t partial train loss (single batch): 0.894758
# \t partial train loss (single batch): 0.895929
# \t partial train loss (single batch): 0.893974
# \t partial train loss (single batch): 0.892366
# \t partial train loss (single batch): 0.892086
# \t partial train loss (single batch): 0.891134
# \t partial train loss (single batch): 0.891142
# \t partial train loss (single batch): 0.891590
# \t partial train loss (single batch): 0.893817
# \t partial train loss (single batch): 0.891779
# \t partial train loss (single batch): 0.893938
# \t partial train loss (single batch): 0.893408
# \t partial train loss (single batch): 0.893272
# \t partial train loss (single batch): 0.893253
# \t partial train loss (single batch): 0.891293
# \t partial train loss (single batch): 0.891218
# \t partial train loss (single batch): 0.893407
# \t partial train loss (single batch): 0.891974
# \t partial train loss (single batch): 0.892863
# \t partial train loss (single batch): 0.891476
# \t partial train loss (single batch): 0.891553
# \t partial train loss (single batch): 0.893933
# \t partial train loss (single batch): 0.892623
# \t partial train loss (single batch): 0.893153
# \t partial train loss (single batch): 0.892660
# \t partial train loss (single batch): 0.892514
# \t partial train loss (single batch): 0.889107
# \t partial train loss (single batch): 0.898022
# \t partial train loss (single batch): 0.893416
# \t partial train loss (single batch): 0.889621
# \t partial train loss (single batch): 0.898598
# \t partial train loss (single batch): 0.891893
# \t partial train loss (single batch): 0.891044
# \t partial train loss (single batch): 0.893113
# \t partial train loss (single batch): 0.893794
# \t partial train loss (single batch): 0.890613
# \t partial train loss (single batch): 0.894238
# \t partial train loss (single batch): 0.900125
# \t partial train loss (single batch): 0.893019
# \t partial train loss (single batch): 0.893046
# \t partial train loss (single batch): 0.888856
# \t partial train loss (single batch): 0.894060
# \t partial train loss (single batch): 0.892232
# \t partial train loss (single batch): 0.889120
# \t partial train loss (single batch): 0.893186
# \t partial train loss (single batch): 0.888498
# \t partial train loss (single batch): 0.890957
# \t partial train loss (single batch): 0.891368
# \t partial train loss (single batch): 0.894370
# \t partial train loss (single batch): 0.896688
# \t partial train loss (single batch): 0.892412
# \t partial train loss (single batch): 0.889242
# \t partial train loss (single batch): 0.896921
# \t partial train loss (single batch): 0.894246
# \t partial train loss (single batch): 0.891768
# \t partial train loss (single batch): 0.895096
# \t partial train loss (single batch): 0.892796
# \t partial train loss (single batch): 0.892372
# \t partial train loss (single batch): 0.893378
# \t partial train loss (single batch): 0.892567
# \t partial train loss (single batch): 0.892854
# \t partial train loss (single batch): 0.893645
# \t partial train loss (single batch): 0.892621
# \t partial train loss (single batch): 0.896034
# \t partial train loss (single batch): 0.891349
# \t partial train loss (single batch): 0.889796
# \t partial train loss (single batch): 0.894326
# \t partial train loss (single batch): 0.887198
# \t partial train loss (single batch): 0.891777
# \t partial train loss (single batch): 0.889169
# \t partial train loss (single batch): 0.892559
# \t partial train loss (single batch): 0.888208
# \t partial train loss (single batch): 0.887370
# \t partial train loss (single batch): 0.891252
# \t partial train loss (single batch): 0.890706
# \t partial train loss (single batch): 0.894421
# \t partial train loss (single batch): 0.889916
# \t partial train loss (single batch): 0.891462
# \t partial train loss (single batch): 0.889514
# \t partial train loss (single batch): 0.892286
# \t partial train loss (single batch): 0.893216
# \t partial train loss (single batch): 0.892078
# \t partial train loss (single batch): 0.894803
# \t partial train loss (single batch): 0.895536
# \t partial train loss (single batch): 0.891855
# \t partial train loss (single batch): 0.894658
# \t partial train loss (single batch): 0.895380
# \t partial train loss (single batch): 0.893950
# \t partial train loss (single batch): 0.890779
# \t partial train loss (single batch): 0.890494
# \t partial train loss (single batch): 0.894350
# \t partial train loss (single batch): 0.886762
# \t partial train loss (single batch): 0.893590
# \t partial train loss (single batch): 0.890862
# \t partial train loss (single batch): 0.893621
# \t partial train loss (single batch): 0.891691
# \t partial train loss (single batch): 0.893206
# \t partial train loss (single batch): 0.888367
# \t partial train loss (single batch): 0.895584
# \t partial train loss (single batch): 0.890180
# \t partial train loss (single batch): 0.891712
# \t partial train loss (single batch): 0.893104
# \t partial train loss (single batch): 0.890970
# \t partial train loss (single batch): 0.892415
# \t partial train loss (single batch): 0.891283
# \t partial train loss (single batch): 0.894179
# \t partial train loss (single batch): 0.890989
# \t partial train loss (single batch): 0.892231
# \t partial train loss (single batch): 0.891844
# \t partial train loss (single batch): 0.891615
# \t partial train loss (single batch): 0.892614
# \t partial train loss (single batch): 0.889993
# \t partial train loss (single batch): 0.894801
# \t partial train loss (single batch): 0.890487
# \t partial train loss (single batch): 0.890761
# \t partial train loss (single batch): 0.892326
# \t partial train loss (single batch): 0.887845
# \t partial train loss (single batch): 0.890494
# \t partial train loss (single batch): 0.893222
# \t partial train loss (single batch): 0.893440
# \t partial train loss (single batch): 0.891854
# \t partial train loss (single batch): 0.892914
# \t partial train loss (single batch): 0.889836
# \t partial train loss (single batch): 0.894283
# \t partial train loss (single batch): 0.889444
# \t partial train loss (single batch): 0.891361
# \t partial train loss (single batch): 0.892735
# \t partial train loss (single batch): 0.891667
# \t partial train loss (single batch): 0.894093
# \t partial train loss (single batch): 0.887863
# \t partial train loss (single batch): 0.893011
# \t partial train loss (single batch): 0.891364
# \t partial train loss (single batch): 0.890500
# \t partial train loss (single batch): 0.892182
# \t partial train loss (single batch): 0.888474
# \t partial train loss (single batch): 0.888848
# \t partial train loss (single batch): 0.893147
# \t partial train loss (single batch): 0.894485
# \t partial train loss (single batch): 0.891604
# \t partial train loss (single batch): 0.890747
# \t partial train loss (single batch): 0.893022
# \t partial train loss (single batch): 0.894173
# \t partial train loss (single batch): 0.893534
# \t partial train loss (single batch): 0.894723
# \t partial train loss (single batch): 0.891132
# \t partial train loss (single batch): 0.889983
# \t partial train loss (single batch): 0.892504
# \t partial train loss (single batch): 0.893040
# \t partial train loss (single batch): 0.894392
# \t partial train loss (single batch): 0.892631
# \t partial train loss (single batch): 0.892549
# \t partial train loss (single batch): 0.890597
# \t partial train loss (single batch): 0.887469
# \t partial train loss (single batch): 0.889258
# \t partial train loss (single batch): 0.889033
# \t partial train loss (single batch): 0.893036
# \t partial train loss (single batch): 0.897209
# \t partial train loss (single batch): 0.894611
# \t partial train loss (single batch): 0.894452
# \t partial train loss (single batch): 0.890165
# \t partial train loss (single batch): 0.892679
# \t partial train loss (single batch): 0.889657
# \t partial train loss (single batch): 0.885887
# \t partial train loss (single batch): 0.896322
# \t partial train loss (single batch): 0.889374
# \t partial train loss (single batch): 0.890744
# \t partial train loss (single batch): 0.887961
# \t partial train loss (single batch): 0.892800
# \t partial train loss (single batch): 0.888659
# \t partial train loss (single batch): 0.894034
# \t partial train loss (single batch): 0.890907
# \t partial train loss (single batch): 0.891266
# \t partial train loss (single batch): 0.890827
# \t partial train loss (single batch): 0.888924
# \t partial train loss (single batch): 0.890842
# \t partial train loss (single batch): 0.893274
# \t partial train loss (single batch): 0.893899
# \t partial train loss (single batch): 0.892999
# \t partial train loss (single batch): 0.891036
# \n EPOCH 20/20 \t train loss 0.892 \t val loss 0.893

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.8917587995529175

# %%
# Train and validation loss

plt.figure(figsize=(7,5))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %% [markdown]
# **Висновок:** У цій лабораторній роботі було реалізовано автокодувальник для розпізнавання зображень рукописних цифр, після додавання гаусівського шуму. Модель складалась з енкодера та декодера, які були реалізовані за допомогою згорткових і лінійних шарів у PyTorch. Після побудови моделі була проведена її тренування та валідація на відповідних наборах даних. У процесі навчання фіксувалися значення функції втрат для навчальної та валідаційної вибірок, які були візуалізовані у вигляді графіка.
